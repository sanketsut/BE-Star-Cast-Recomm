# %%
import pandas as pd
import numpy as np
from collections import Counter
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv('files/castgenre.csv')

# %%
genre_input = 'horror'
a1 = df[df['Genre 1'] == genre_input.capitalize()]
a2 = df[df['Genre 2'] == genre_input.capitalize()]
a3 = df[df['Genre 3'] == genre_input.capitalize()]
c = a1.append(a2, ignore_index=True).append(a3, ignore_index=True)
c.head()
# Out:
#    Unnamed: 0                                             actors Genre 1  \
# 0         129  Ajay Devgn | Urmila Matondkar | Nana Patekar |...  Horror
# 1         158  Sameera Reddy | Antara Mali | Sohail Khan | Sa...  Horror
# 2         164  Tanisha | Dino Morea | Karan Nath | Gaurav Kapoor  Horror
# 3         192  Tabu | Shahbaaz Khan | Mukesh Tiwari | Imran Khan  Horror
# 4         254  Amitabh Bachchan | Dimple Kapadia | Dharmendra...  Horror
#
#      Genre 2  Genre 3
# 0   Thriller      NaN
# 1  Adventure      NaN
# 2    Mystery      NaN
# 3   Thriller      NaN
# 4      Drama  Mystery

# %%
actors = c['actors']
x = []
for i in range(len(actors)):
    a = str(actors[i]).split('|')
    a = [z.strip() for z in a]
    x.append(a)

# %%
te = TransactionEncoder()
te = te.fit(x)
te_ary = te.transform(x)

# %%
def eval_func(a):
    return eval(str(a))
def mul_func(a):
    return int(a)*10
def make_list(a):
    return list(a)

# %%
frequent_itemsets = apriori(dffd, min_support =0.0015,use_colnames=True)
frequent_itemsets.to_csv('files/horror.csv')

# %%
dffd = pd.DataFrame(te_ary,columns=te.columns_)

# %%
df2 = pd.read_csv('files/TopActors.csv')
df2 = df2.drop(columns=['Unnamed: 0'])
df2['Top 10 Actors'] = df2['Top 10 Actors'].apply(eval_func)

# %%
df2['Genre'][8]
# Out:
# 'Documentary'

# %%
#genre_list = ['Adventure','Action','Comedy','Crime','Drama','Family','Fantasy','Thriller','Romance','Horror','Musical']
input_genre = 'Adventure'
try:
    working_with = pd.read_csv('files/adventure.csv')
    working_with = working_with.drop(columns=['Unnamed: 0'])
except FileNotFoundError:
    print('File Not found')

# %%
import random

# %%
abascus = list(df2[df2['Genre'] == input_genre.capitalize()]['Top 10 Actors'])
top_actor = abascus[0][random.randint(0,9)][0]

# %% [markdown]
# # normalized rating, charge, genres, name

# %%
working_with['itemsets'] = working_with['itemsets'].apply(eval_func)
working_with['support'] = working_with['support'].apply(eval_func)

# %%
from mlxtend.frequent_patterns import association_rules
rules = association_rules(working_with,metric='confidence',min_threshold=0.001)

# %%
rules
# Out:
#                                           antecedents  \
# 0                                 (Abhishek Bachchan)
# 1                                  ('Chiyaan' Vikram)
# 2                                  ('Chiyaan' Vikram)
# 3                            (Aishwarya Rai Bachchan)
# 4                                           (Govinda)
# 5                                  ('Chiyaan' Vikram)
# 6                                      (Aakshi Khari)
# 7                                     (Hemant Pandey)
# 8                                      (Aakshi Khari)
# 9                                     (Sumeet Sharma)
# 10                                      (Gracy Singh)
# 11                                       (Aamir Khan)
# 12                                       (Aamir Khan)
# 13                                 (Paul Blackthorne)
# 14                                       (Aamir Khan)
# 15                                   (Rachel Shelley)
# ...

# %%
a = rules[rules['antecedents'].apply(lambda x:set([top_actor]).issubset(x))]['consequents'].apply(make_list)

# %%
a = rules[rules['antecedents'].apply(lambda x:set(['Aamir Khan']).issubset(x))]['consequents']

# %%
b= list(a.values)

# %%
c= [x for x in b if len(x)>0]

# %%
b
# Out:
# [frozenset({'Gracy Singh'}),
#  frozenset({'Paul Blackthorne'}),
#  frozenset({'Rachel Shelley'}),
#  frozenset({'Paul Blackthorne'}),
#  frozenset({'Gracy Singh'}),
#  frozenset({'Gracy Singh', 'Paul Blackthorne'}),
#  frozenset({'Rachel Shelley'}),
#  frozenset({'Gracy Singh'}),
#  frozenset({'Gracy Singh', 'Rachel Shelley'}),
#  frozenset({'Paul Blackthorne'}),
#  frozenset({'Rachel Shelley'}),
#  frozenset({'Paul Blackthorne', 'Rachel Shelley'}),
#  frozenset({'Paul Blackthorne'}),
#  frozenset({'Rachel Shelley'}),
#  frozenset({'Gracy Singh'}),
#  frozenset({'Paul Blackthorne', 'Rachel Shelley'}),
#  frozenset({'Gracy Singh', 'Paul Blackthorne'}),
#  frozenset({'Gracy Singh', 'Rachel Shelley'}),
#  frozenset({'Gracy Singh', 'Paul Blackthorne', 'Rachel Shelley'})]

# %%
actor_df = pd.read_csv('files/BollywoodActorRanking.csv')
actor_df = actor_df.drop(columns = ['movieCount','ratingSum','actorId','normalizedMovieRank','Unnamed: 8','DOA'])

# %%
rules
# Out:
#                                             antecedents  \
# 0                                                    ()
# 1                                          (Ajay Devgn)
# 2                                         (Boman Irani)
# 3                                          (Aamir Khan)
# 4                                         (Juhi Chawla)
# 5                                          (Aamir Khan)
# 6                                               (Kajol)
# 7                                          (Aamir Khan)
# 8                                      (Kareena Kapoor)
# 9                                          (Aamir Khan)
# 10                                    (Manisha Koirala)
# 11                                         (Aamir Khan)
# 12                                       (Rani Mukerji)
# 13                                         (Aamir Khan)
# 14                                      (Sharman Joshi)
# 15                                         (Aamir Khan)
# ...

# %%
actor_df.head()
# Out:
#           actorName  googleHits  normalizedGoogleRank  normalizedRating
# 0        Aamir Khan     2460000               7.34283          10.00000
# 1    Shah Rukh Khan     2670000               7.88458           9.22674
# 2       Salman Khan     3490000              10.00000           9.20821
# 3      Katrina Kaif     2120000               6.46570           8.94852
# 4  Deepika Padukone     3000000               8.73591           8.62716

# %%
gh = pd.read_csv('files/TopGenres.csv')
gh.head()
gh = gh.drop(columns=['Unnamed: 0'])

# %%
actor_df = actor_df.rename(index=str, columns = {'actorName':'Actor Name'})
gh = gh.rename(index = str, columns={'Actor':'Actor Name'})

# %%
fin = actor_df.set_index('Actor Name').join(gh.set_index('Actor Name'))

# %%
fin = dropn
# Out:
# <bound method DataFrame.count of                         googleHits  normalizedGoogleRank  normalizedRating  \
# Actor Name
# Aamir Khan                    True                  True              True
# Shah Rukh Khan                True                  True              True
# Salman Khan                   True                  True              True
# Katrina Kaif                  True                  True              True
# Deepika Padukone              True                  True              True
# Hrithik Roshan                True                  True              True
# Priyanka Chopra               True                  True              True
# Kareena Kapoor                True                  True              True
# Ranbir Kapoor                 True                  True              True
# Kajol                         True                  True              True
# John Abraham                  True                  True              True
# ...

# %%
fin.shape
# Out:
# (189, 5)

# %%
dict = {'Name':fin.index}

# %%
def knapSack(W, wt, val, n): 
  
    # Base Case 
    if n == 0 or W == 0 : 
        return 0
  
    # If weight of the nth item is more than Knapsack of capacity 
    # W, then this item cannot be included in the optimal solution 
    if (wt[n-1] > W): 
        return knapSack(W, wt, val, n-1) 
  
    # return the maximum of two cases: 
    # (1) nth item included 
    # (2) not included 
    else: 
        return max(val[n-1] + knapSack(W-wt[n-1], wt, val, n-1), 
                   knapSack(W, wt, val, n-1)) 
  
# end of function knapSack

# %%
a =
# Out:
#               googleHits  normalizedGoogleRank  normalizedRating  \
# Actor Name
# Bipasha Basu     1050000               3.70534           4.57122
#
#                                                   Top Genres          name
# Actor Name
# Bipasha Basu  [('Drama', 19), ('Crime', 10), ('Action', 10)]  Bipasha Basu
